# %%
import pandas as pd

# %%
# performthe following operations using python on suitable data sets:
# a. read data from different formats(like csv, xls)

readFile = pd.read_excel("/content/sample_data/Employee Sample Data.xlsx")
print(readFile)

# %%
# b.indexing and selecting data, sort data.
# indexing by col name.
readFile["Full Name"]
# Out:
# 0          Emily Davis
# 1        Theodore Dinh
# 2         Luna Sanders
# 3      Penelope Jordan
# 4            Austin Vo
#             ...
# 995       Wesley Young
# 996       Lillian Khan
# 997        Oliver Yang
# 998        Lily Nguyen
# 999        Sofia Cheng
# Name: Full Name, Length: 1000, dtype: object

# %%
# by using row index and column index :
readFile.iloc[2:10 , 4:10]

# %%
# selecting data:
readFile.iloc[:20, :20]

# %%
# describe attributes of data, checking data types of each column .
readFile.describe()

# %%
print(type(readFile))

# %%
# counting unique value of data, format of each column, converting variables datatypes.
print(pd.unique(readFile['Department']))
print(len(pd.unique(readFile['Department'])))

# %%
# converting data types:
convert = {'Annual Salary' : float}
file1 = readFile.astype(convert)
print(file1.dtypes)

# %%
file1.head()

# %%
# sorting data according to Department
readFile.sort_values(by=['Department'])

# %%
#identify the missing values
readFile.isnull()
